# %%
#! /usr/bin/python3
from numpy import *
import matplotlib.pyplot as plt # from pylab import plot,show
import warnings
warnings.filterwarnings("ignore")

#################################### Fin del encabezado

import scipy.constants as constants #para la constante g
from mpl_toolkits.mplot3d import Axes3D
from math import *
from MACHADO_modulo import *
################################################################################

#4-dirichlet

maxIter = 1000

lenX = lenY = 10
delta = 0.1

Ttop = 100
Tbottom = 0
Tleft = 75
Tright = 50

Tguess = 0


colorinterpolation = 50
colourMap = plt.cm.jet #colourMap = plt.cm.coolwarm

X, Y = meshgrid(arange(0, lenX + delta ,delta), arange(0, lenY + delta,delta))

print(len(X))

#print(X,Y)
T = empty((len(X), len(Y)))
T.fill(Tguess)

#print(T)

#condiciones de contorno
T[(len(Y)-1):, :] = Ttop
T[:1, :] = Tbottom
T[:, (len(X)-1):] = Tright
T[:, :1] = Tleft

#print(T)

for iteration in range(0, maxIter):
    for i in range(1, len(X)-1):
        for j in range(1, len(Y)-1):
            T[i, j] = 0.25 * (T[i+1][j] + T[i-1][j] + T[i][j+1] + T[i][j-1])



#print(T)

plt.title("Heat Map: 4-Dirichlet")
plt.contourf(X, Y, T, colorinterpolation, cmap=colourMap)
plt.colorbar()
plt.show()
# Out:
# 101

# %%
# 1-neuman y 3-dirichlet

maxIter = 5000

lenX = lenY = 10
delta = 0.1

Ttop = 100
Tbottom = 0
Tleft = 75
Tright = 50

Tguess = 0


colorinterpolation = 50
colourMap = plt.cm.jet #colourMap = plt.cm.coolwarm

X, Y = meshgrid(arange(0, lenX + delta ,delta), arange(0, lenY + delta,delta))

#print(X,Y)
T = empty((len(X), len(Y)))
T.fill(Tguess)

#print(T)

#condiciones de contorno
T[(len(Y)-1):, :] = Ttop
T[:1, :] = Tbottom
T[:, (len(X)-1):] = Tright
T[:, :1] = Tleft

#print(T)

for iteration in range(0, maxIter):
    for i in range(0, len(X)-1):
        for j in range(1, len(Y)-1):
            if i != 0:
                T[i, j] = 0.25 * (T[i+1][j] + T[i-1][j] + T[i][j+1] + T[i][j-1])
            if i == 0:
                if j == 1:
                    T[i, j] = 0.5 * (T[i+1][j] + T[i][j+1])
                if j == len(Y)-2:
                    T[i, j] = 0.5 * (T[i+1][j] + T[i][j-1])
                else :
                    T[i, j] = 0.25 * (T[i][j-1] + T[i][j+1] + 2*T[i+1][j])
                
                #if j != 1 and j!= len(Y)-1:
                 #   T[i, j] = 0.25 * (T[i+1][j] + T[i-1][j] + 2*T[i][j+1])
                #else:
                 #   T[i, j] = 0.25 * (T[i+1][j] + T[i-1][j] + 2*T[i][j+1])

            #if i == 0:
            #    T[i, j] = 0.25 * (T[i][j+1] + T[i][j-1] + 2*T[i+1][j])



#print(T)

plt.title("Heat Map: 1-Neumann and 3-Dirichlet")
plt.contourf(X, Y, T, colorinterpolation, cmap=colourMap)
plt.colorbar()
plt.show()
print("ok")

################################################################################
# Out:
# ok

# %%
#2-neuman, 2 dirichlet

maxIter = 5000

lenX = lenY = 50
delta = 0.5

Ttop = 100
Tbottom = 0
Tleft = 75
Tright = 50

Tguess = 0


colorinterpolation = 50
colourMap = plt.cm.jet #colourMap = plt.cm.coolwarm

X, Y = meshgrid(arange(0, lenX + delta ,delta), arange(0, lenY + delta,delta))

#print(X,Y)
T = empty((len(X), len(Y)))
T.fill(Tguess)

#print(T)

#condiciones de contorno
T[(len(Y)-1):, :] = Ttop
T[:1, :] = Tbottom
T[:, (len(X)-1):] = Tright
T[:, :1] = Tleft

#print(T)

for iteration in range(0, maxIter):
    for i in range(0, len(X)):
        for j in range(1, len(Y)-1):
            if i == 0:
                if j == 1:
                    T[i, j] = 0.5 * (T[i+1][j] + T[i][j+1])
                if j == len(Y)-2:
                    T[i, j] = 0.5 * (T[i+1][j] + T[i][j-1])
                else :
                    T[i, j] = 0.25 * (T[i][j-1] + T[i][j+1] + 2*T[i+1][j])
            if i == len(X)-1:
                if j == 1:
                    T[i, j] = 0.5 * (T[i-1][j] + T[i][j+1])
                if j == len(Y)-2:
                    T[i, j] = 0.5 * (T[i-1][j] + T[i][j-1])
                else :
                    T[i, j] = 0.25 * (T[i][j-1] + T[i][j+1] + 2*T[i-1][j])
            else:
                T[i, j] = 0.25 * (T[i+1][j] + T[i-1][j] + T[i][j+1] + T[i][j-1])

            #if i == 0:
            #    T[i, j] = 0.25 * (T[i][j+1] + T[i][j-1] + 2*T[i+1][j])



#print(T)

plt.title("Heat Map: 2-Neumann and 2-Dirichlet")
plt.contourf(X, Y, T, colorinterpolation, cmap=colourMap)
plt.colorbar()
plt.show()

################################################################################

# %%
#2-neuman, 2 dirichlet #2

maxIter = 5000

lenX = lenY = 50
delta = 0.5

Ttop = 100
Tbottom = 0
Tleft = 0
Tright = 50

Tguess = 0


colorinterpolation = 50
colourMap = plt.cm.jet #colourMap = plt.cm.coolwarm

X, Y = meshgrid(arange(0, lenX + delta ,delta), arange(0, lenY + delta,delta))

#print(X,Y)
T = empty((len(X), len(Y)))
T.fill(Tguess)

#print(T)

#condiciones de contorno
T[(len(Y)-1):, :] = Ttop
T[:1, :] = Tbottom
T[:, (len(X)-1):] = Tright
T[:, :1] = Tleft

#print(T)

for iteration in range(0, maxIter):
    for i in range(0, len(X)-1):
        for j in range(0, len(Y)-1):
            if i == 0:
                if j == 0:
                    T[i, j] = 0.5 * (T[i+1][j] + T[i][j+1])
                if j == len(Y)-1:
                    T[i, j] = 0.5 * (T[i+1][j] + T[i][j-1])
                else :
                    T[i, j] = 0.25 * (T[i][j-1] + T[i][j+1] + 2*T[i+1][j])
            if j == 0:
                if i == len(X)-2:
                    T[i, j] = 0.5 * (T[i-1][j] + T[i][j+1])
                else :
                    T[i, j] = 0.25 * (T[i-1][j] + T[i+1][j] + 2*T[i][j+1])
            else:
                T[i, j] = 0.25 * (T[i+1][j] + T[i-1][j] + T[i][j+1] + T[i][j-1])

            #if i == 0:
            #    T[i, j] = 0.25 * (T[i][j+1] + T[i][j-1] + 2*T[i+1][j])



#print(T)

plt.title("Heat Map: 2-Neumann and 2-Dirichlet")
plt.contourf(X, Y, T, colorinterpolation, cmap=colourMap)
plt.colorbar()
plt.show()

################################################################################

# %%
################################################################################
from matplotlib.colors import LogNorm

#4-dirichlet (fx)

maxIter = 1000

lenX = lenY = 10
delta = 0.1

def f_top(x):
    return (x-5)**2

def f_bottom(x):
    return (sin(x))**2

def f_left(x):
    return x+10

def f_right(x):
    return x/2
    


Ttop = 100
Tbottom = 0
Tleft = 75
Tright = 50

Tguess = 0


colorinterpolation = 50
colourMap = plt.cm.jet #colourMap = plt.cm.coolwarm

X, Y = meshgrid(arange(0, lenX + delta ,delta), arange(0, lenY + delta,delta))

print(len(X))

#print(X,Y)
T = empty((len(X), len(Y)))
T.fill(Tguess)

#print(T)




#condiciones de contorno
for j in range(0,len(X)):
    T[0,j] = f_bottom(j*delta)
    T[len(Y)-1,j] = f_top(j*delta)
    
for i in range(0,len(Y)):
    T[i,0] = f_left(i*delta)
    T[i,len(X)-1] = f_right(i*delta)    


#T[(len(Y)-1):, :] = Ttop
#T[:1, :] = Tbottom
#T[:, (len(X)-1):] = Tright
#T[:, :1] = Tleft

#print(T)

for iteration in range(0, maxIter):
    for i in range(1, len(X)-1):
        for j in range(1, len(Y)-1):
            T[i, j] = 0.25 * (T[i+1][j] + T[i-1][j] + T[i][j+1] + T[i][j-1])



#print(T)

plt.title("Heat Map: 4-Dirichlet")
plt.contourf(X, Y, T, colorinterpolation, cmap=colourMap)  #, norm=LogNorm()
plt.colorbar()
plt.show()
# Out:
# 101

# %%
################################################################################
from matplotlib.colors import LogNorm

#4-dirichlet (fx)

maxIter = 1000

lenX = lenY = 10
delta = 0.1

def f_top(x):
    return (sqrt(x)*cos(3*x))**(2)*3

def f_bottom(x):
    return (sin(x))**3

def f_left(x):
    return ((3*cos(x)+2*sin(5*x))**2)*1.5

def f_right(x):
    return (abs((sin(x))**3))*20
    


Ttop = 100
Tbottom = 0
Tleft = 75
Tright = 50

Tguess = 0


colorinterpolation = 50
colourMap = plt.cm.jet #colourMap = plt.cm.coolwarm

X, Y = meshgrid(arange(0, lenX + delta ,delta), arange(0, lenY + delta,delta))

print(len(X))

#print(X,Y)
T = empty((len(X), len(Y)))
T.fill(Tguess)

#print(T)




#condiciones de contorno
for j in range(0,len(X)):
    T[0,j] = f_bottom(j*delta)
    T[len(Y)-1,j] = f_top(j*delta)
    
for i in range(0,len(Y)):
    T[i,0] = f_left(i*delta)
    T[i,len(X)-1] = f_right(i*delta)    


#T[(len(Y)-1):, :] = Ttop
#T[:1, :] = Tbottom
#T[:, (len(X)-1):] = Tright
#T[:, :1] = Tleft

#print(T)

for iteration in range(0, maxIter):
    for i in range(1, len(X)-1):
        for j in range(1, len(Y)-1):
            T[i, j] = 0.25 * (T[i+1][j] + T[i-1][j] + T[i][j+1] + T[i][j-1])



#print(T)

plt.title("Heat Map: 4-Dirichlet")
plt.contourf(X, Y, T, colorinterpolation, cmap=colourMap)  #, norm=LogNorm()
plt.colorbar()
plt.show()
# Out:
# 101

# %%
# 1-neuman y 3-dirichlet (fx)

maxIter = 1000

lenX = lenY = 10
delta = 0.1

def f_top(x):
    return (sqrt(x)*cos(3*x))**(2)*3

def f_bottom(x):
    return (sin(x))**3

def f_left(x):
    return ((3*cos(x)+2*sin(5*x))**2)*1.5

def f_right(x):
    return (abs((sin(x))**3))*20

Ttop = 100
Tbottom = 0
Tleft = 75
Tright = 50

Tguess = 0


colorinterpolation = 50
colourMap = plt.cm.jet #colourMap = plt.cm.coolwarm

X, Y = meshgrid(arange(0, lenX + delta ,delta), arange(0, lenY + delta,delta))

#print(X,Y)
T = empty((len(X), len(Y)))
T.fill(Tguess)

#print(T)


#condiciones de contorno
for j in range(0,len(X)):
    T[0,j] = 0
    T[len(Y)-1,j] = f_top(j*delta)
    
for i in range(0,len(Y)):
    T[i,0] = f_left(i*delta)
    T[i,len(X)-1] = f_right(i*delta) #l intead of i to avoid complex mistake  

#condiciones de contorno
#T[(len(Y)-1):, :] = Ttop
#T[:1, :] = Tbottom
#T[:, (len(X)-1):] = Tright
#T[:, :1] = Tleft

#print(T)

for iteration in range(0, maxIter):
    for i in range(0, len(X)-1):
        for j in range(1, len(Y)-1):
            if i != 0:
                T[i, j] = 0.25 * (T[i+1][j] + T[i-1][j] + T[i][j+1] + T[i][j-1])
            if i == 0:
                if j == 1:
                    T[i, j] = 0.5 * (T[i+1][j] + T[i][j+1])
                if j == len(Y)-2:
                    T[i, j] = 0.5 * (T[i+1][j] + T[i][j-1])
                else :
                    T[i, j] = 0.25 * (T[i][j-1] + T[i][j+1] + 2*T[i+1][j])
                
                #if j != 1 and j!= len(Y)-1:
                 #   T[i, j] = 0.25 * (T[i+1][j] + T[i-1][j] + 2*T[i][j+1])
                #else:
                 #   T[i, j] = 0.25 * (T[i+1][j] + T[i-1][j] + 2*T[i][j+1])

            #if i == 0:
            #    T[i, j] = 0.25 * (T[i][j+1] + T[i][j-1] + 2*T[i+1][j])



#print(T)

plt.title("Heat Map: 1-Neumann and 3-Dirichlet")
plt.contourf(X, Y, T, colorinterpolation, cmap=colourMap)
plt.colorbar()
plt.show()
print("ok")

################################################################################
# Out:
# ok

# %%
#2-neuman, 2 dirichlet #2
maxIter = 1000

lenX = lenY = 5
delta = 0.05

def f_top(x):
    return 25*abs(sin(x**x))/(2**((x**x-pi/2)/pi))

def f_bottom(x):
    return (sin(x))**3

def f_left(x):
    return ((3*cos(x)+2*sin(5*x))**2)*1.5

def f_right(x):
    return 20*(sin(2*sin(2*sin(2*sin(5*x))))+1)

Ttop = 100
Tbottom = 0
Tleft = 0
Tright = 50

Tguess = 0


colorinterpolation = 50
colourMap = plt.cm.jet #colourMap = plt.cm.coolwarm

X, Y = meshgrid(arange(0, lenX + delta ,delta), arange(0, lenY + delta,delta))

#print(X,Y)
T = empty((len(X), len(Y)))
T.fill(Tguess)

#print(T)

#condiciones de contorno
for j in range(0,len(X)):
    T[0,j] = 0
    T[len(Y)-1,j] = f_top(j*delta)
    
for i in range(0,len(Y)):
    T[i,0] = 0
    T[i,len(X)-1] = f_right(i*delta) #l intead of i to avoid complex mistake  

#print(T)

for iteration in range(0, maxIter):
    for i in range(0, len(X)-1):
        for j in range(0, len(Y)-1):
            if i == 0:
                if j == 0:
                    T[i, j] = 0.5 * (T[i+1][j] + T[i][j+1])
                if j == len(Y)-1:
                    T[i, j] = 0.5 * (T[i+1][j] + T[i][j-1])
                else :
                    T[i, j] = 0.25 * (T[i][j-1] + T[i][j+1] + 2*T[i+1][j])
            if j == 0:
                if i == len(X)-2:
                    T[i, j] = 0.5 * (T[i-1][j] + T[i][j+1])
                else :
                    T[i, j] = 0.25 * (T[i-1][j] + T[i+1][j] + 2*T[i][j+1])
            else:
                T[i, j] = 0.25 * (T[i+1][j] + T[i-1][j] + T[i][j+1] + T[i][j-1])

            #if i == 0:
            #    T[i, j] = 0.25 * (T[i][j+1] + T[i][j-1] + 2*T[i+1][j])



#print(T)

plt.title("Heat Map: 2-Neumann and 2-Dirichlet")
plt.contourf(X, Y, T, colorinterpolation, cmap=colourMap)
plt.colorbar()
plt.show()

################################################################################

# %%
#2-neuman, 2 dirichlet
maxIter = 1000

lenX = lenY = 10
delta = 0.1

def f_top(x):
    return (sqrt(x)*cos(3*x))**(2)*3

def f_bottom(x):
    return (sin(x))**3

def f_left(x):
    return ((3*cos(x)+2*sin(5*x))**2)*1.5

def f_right(x):
    return (abs((sin(x))**3))*20
Ttop = 100
Tbottom = 0
Tleft = 75
Tright = 50

Tguess = 0


colorinterpolation = 50
colourMap = plt.cm.jet #colourMap = plt.cm.coolwarm

X, Y = meshgrid(arange(0, lenX + delta ,delta), arange(0, lenY + delta,delta))

#print(X,Y)
T = empty((len(X), len(Y)))
T.fill(Tguess)

#print(T)

#condiciones de contorno
for j in range(0,len(X)):
    T[0,j] = 0
    T[len(Y)-1,j] = 0
    
for i in range(0,len(Y)):
    T[i,0] = f_left(i*delta)
    T[i,len(X)-1] = f_right(i*delta) #l intead of i to avoid complex mistake  
#print(T)

for iteration in range(0, maxIter):
    for i in range(0, len(X)):
        for j in range(1, len(Y)-1):
            if i == 0:
                if j == 1:
                    T[i, j] = 0.5 * (T[i+1][j] + T[i][j+1])
                if j == len(Y)-2:
                    T[i, j] = 0.5 * (T[i+1][j] + T[i][j-1])
                else :
                    T[i, j] = 0.25 * (T[i][j-1] + T[i][j+1] + 2*T[i+1][j])
            if i == len(X)-1:
                if j == 1:
                    T[i, j] = 0.5 * (T[i-1][j] + T[i][j+1])
                if j == len(Y)-2:
                    T[i, j] = 0.5 * (T[i-1][j] + T[i][j-1])
                else :
                    T[i, j] = 0.25 * (T[i][j-1] + T[i][j+1] + 2*T[i-1][j])
            else:
                T[i, j] = 0.25 * (T[i+1][j] + T[i-1][j] + T[i][j+1] + T[i][j-1])

            #if i == 0:
            #    T[i, j] = 0.25 * (T[i][j+1] + T[i][j-1] + 2*T[i+1][j])



#print(T)

plt.title("Heat Map: 2-Neumann and 2-Dirichlet")
plt.contourf(X, Y, T, colorinterpolation, cmap=colourMap)
plt.colorbar()
plt.show()

################################################################################

# %%
def f_top(x):
    return abs(sin(x**x))/(2**((x**x-pi/2)/pi))

f_top(5)
# Out:
# 3.972137157307088e-300
